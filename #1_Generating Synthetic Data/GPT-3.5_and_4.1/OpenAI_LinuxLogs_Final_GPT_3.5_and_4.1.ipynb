# %%
import os
import pandas as pd
import numpy as np
import re
from collections import Counter
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install --upgrade --quiet pip
# %pip install --upgrade --quiet  langchain langchain_experimental langchain-openai pydantic==2.9.2 openai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 54.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 66.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 60.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 755.6/755.6 kB 27.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13/13 [langchain_experimental]

# %%
from langchain.prompts import FewShotPromptTemplate, PromptTemplate
from pydantic import BaseModel
from langchain_experimental.tabular_synthetic_data.openai import create_openai_data_generator
from langchain_experimental.tabular_synthetic_data.prompts import (
    SYNTHETIC_FEW_SHOT_PREFIX,
    SYNTHETIC_FEW_SHOT_SUFFIX,
)
from langchain_openai import ChatOpenAI

# %%
from typing import Optional, Union, Dict

# %%
import re

def parse_log_line(line: str) -> dict:
    # Extract timestamp
    timestamp_match = re.search(r"\[(.*?)\]", line)
    timestamp = timestamp_match.group(1) if timestamp_match else ""

    # Extract time elapsed
    time_elapsed_match = re.search(r"\((.*?)\)", line)
    time_elapsed = time_elapsed_match.group(1) if time_elapsed_match else ""

    # Extract host name and event name
    parts = line.split()
    host_name = parts[2] if len(parts) > 2 else ""
    event_name = parts[3].rstrip(":") if len(parts) > 3 else ""

    # Extract all {...} blocks
    curly_groups = re.findall(r"\{(.*?)\}", line)

    # Initialize fields
    cpu_id = "0"
    process_details = ""
    kernel_details = ""

    # Extract CPU ID from first group (if present)
    if len(curly_groups) >= 1:
        cpu_match = re.search(r"cpu_id\s*=\s*(\d+)", curly_groups[0])
        cpu_id = cpu_match.group(1) if cpu_match else "0"

    # Clean and assign process/kernel details (remove quotes)
    if len(curly_groups) >= 2:
        process_details = curly_groups[1].replace('"', '').replace("'", "").strip()
    if len(curly_groups) >= 3:
        kernel_details = curly_groups[2].replace('"', '').replace("'", "").strip()

    # Build formatted example string and escape all curly braces for PromptTemplate
    formatted = (
        f"timestamp:{timestamp}, time elapsed: (+{time_elapsed}), Host Name: {host_name}, "
        f"Event Name: {event_name}, Cpu Id: {cpu_id}, process_details: {process_details}, "
        f"kernel_details: {kernel_details}"
    )

    # Escape all braces for safe PromptTemplate use
    escaped_formatted = formatted.replace("{", "{{").replace("}", "}}")

    return {"example": escaped_formatted}

# %%
logs = []
with open("kernel_trace_1K.txt", "r") as file:
    for line in file:
        if line.strip():
            try:
                parsed = parse_log_line(line.strip())
                logs.append(parsed)
            except Exception as e:
                print(f"Error parsing line: {line}\n{e}")

# %%
logs
# Out:
# [{'example': 'timestamp:06:13:02.227908688, time elapsed: (++?.?????????), Host Name: mendax, Event Name: syscall_entry_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 553, upeer_addrlen = 246916502706640'},
#  {'example': 'timestamp:06:13:02.227912438, time elapsed: (++0.000003750), Host Name: mendax, Event Name: syscall_exit_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 576, upeer_sockaddr = 246916502706648, upeer_addrlen = 246916502706640'},
#  {'example': 'timestamp:06:13:02.227914646, time elapsed: (++0.000002208), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 3, arg = 50'},
#  {'example': 'timestamp:06:13:02.227914980, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 2, arg = 50'},
#  {'example': 'timestamp:06:13:02.227916313, time elapsed: (++0.000001333), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, usockaddr_len = 246916502706368'},
#  {'example': 'timestamp:06:13:02.227916771, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, usockaddr = 246916502706376, usockaddr_len = 246916502706368'},
#  {'example': 'timestamp:06:13:02.227917438, time elapsed: (++0.000000667), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, usockaddr_len = 246916502706372'},
#  {'example': 'timestamp:06:13:02.227917855, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, usockaddr = 246916502706376, usockaddr_len = 246916502706372'},
#  {'example': 'timestamp:06:13:02.227923813, time elapsed: (++0.000005958), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 3, arg = 50'},
#  {'example': 'timestamp:06:13:02.227923979, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 2, arg = 50'},
#  {'example': 'timestamp:06:13:02.227924188, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 4, arg = 2050'},
#  {'example': 'timestamp:06:13:02.227924354, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, arg = 2050'},
#  {'example': 'timestamp:06:13:02.227927646, time elapsed: (++0.000003292), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 6, optname = 1, optval = 246916502705868, optlen = 4'},
#  {'example': 'timestamp:06:13:02.227928063, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.227928771, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502705996'},
#  {'example': 'timestamp:06:13:02.227929146, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706080, optlen = 246916502705996'},
#  {'example': 'timestamp:06:13:02.227930021, time elapsed: (++0.000000875), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502706412'},
#  {'example': 'timestamp:06:13:02.227930188, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706496, optlen = 246916502706412'},
#  {'example': 'timestamp:06:13:02.227930562, time elapsed: (++0.000000374), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502706412'},
#  {'example': 'timestamp:06:13:02.227930729, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706496, optlen = 246916502706412'},
#  {'example': 'timestamp:06:13:02.227933937, time elapsed: (++0.000003208), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 6, optname = 1, optval = 246916502705964, optlen = 4'},
#  {'example': 'timestamp:06:13:02.227934187, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.227934646, time elapsed: (++0.000000459), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 9, optval = 246916502705836, optlen = 4'},
#  {'example': 'timestamp:06:13:02.227935021, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.227935562, time elapsed: (++0.000000541), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 2, optval = 246916502705836, optlen = 4'},
#  {'example': 'timestamp:06:13:02.227935729, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.227938146, time elapsed: (++0.000002417), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 549, buf = 246916502706248, count = 8'},
#  {'example': 'timestamp:06:13:02.227940521, time elapsed: (++0.000002375), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 8'},
#  {'example': 'timestamp:06:13:02.227944020, time elapsed: (++0.000003499), Host Name: mendax, Event Name: syscall_entry_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: epfd = 542, maxevents = 1024, timeout = -1, sigmask = 0x0, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.227946729, time elapsed: (++0.000002709), Host Name: mendax, Event Name: syscall_exit_connect, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -115'},
#  {'example': 'timestamp:06:13:02.227947687, time elapsed: (++0.000000958), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, usockaddr_len = 281474913772420'},
#  {'example': 'timestamp:06:13:02.227948062, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, usockaddr = 281474913772424, usockaddr_len = 281474913772420'},
#  {'example': 'timestamp:06:13:02.227949604, time elapsed: (++0.000001542), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773656, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.227949979, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'},
#  {'example': 'timestamp:06:13:02.227951854, time elapsed: (++0.000001875), Host Name: mendax, Event Name: syscall_entry_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: tsp = 281474913773856, sigmask = 0, sigsetsize = 0, nfds = 2, fds_length = 2, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x4, events = {{ POLLIN = 0, POLLPRI = 0, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.227953062, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_exit_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 1, nfds = 2, fds_length = 1, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x4, events = {{ POLLIN = 0, POLLPRI = 0, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.227953437, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 0, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.227953604, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 281474913773616'},
#  {'example': 'timestamp:06:13:02.227953770, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773464, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.227953895, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'},
#  {'example': 'timestamp:06:13:02.227954562, time elapsed: (++0.000000667), Host Name: mendax, Event Name: syscall_entry_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: tsp = 281474913772720, sigmask = 0, sigsetsize = 0, nfds = 1, fds_length = 1, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x106, events = {{ POLLIN = 0, POLLPRI = 1, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.227955020, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_exit_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 1, nfds = 1, fds_length = 1, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x104, events = {{ POLLIN = 0, POLLPRI = 0, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.227955353, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, level = 1, optname = 4, optlen = 281474913772816'},
#  {'example': 'timestamp:06:13:02.227955645, time elapsed: (++0.000000292), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, optval = 281474913772820, optlen = 281474913772816'},
#  {'example': 'timestamp:06:13:02.227955853, time elapsed: (++0.000000208), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, usockaddr_len = 281474913772420'},
#  {'example': 'timestamp:06:13:02.227956020, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, usockaddr = 281474913772424, usockaddr_len = 281474913772420'},
#  {'example': 'timestamp:06:13:02.227959145, time elapsed: (++0.000003125), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247760, op = 129, val = 2147483647, utime = 0, uaddr2 = 203053665022808, val3 = 496169800'},
#  {'example': 'timestamp:06:13:02.227961395, time elapsed: (++0.000002250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247760, uaddr2 = 203053665022808'},
#  {'example': 'timestamp:06:13:02.228003894, time elapsed: (++0.000042499), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228005269, time elapsed: (++0.000001375), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228012394, time elapsed: (++0.000007125), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665202176'},
#  {'example': 'timestamp:06:13:02.228013435, time elapsed: (++0.000001041), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665202176'},
#  {'example': 'timestamp:06:13:02.228113141, time elapsed: (++0.000099706), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: brk = 222501009338368'},
#  {'example': 'timestamp:06:13:02.228113849, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 222501009338368'},
#  {'example': 'timestamp:06:13:02.228174223, time elapsed: (++0.000060374), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228174556, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228181389, time elapsed: (++0.000006833), Host Name: mendax, Event Name: syscall_entry_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: buf = 222501009261744, count = 48, flags = 0'},
#  {'example': 'timestamp:06:13:02.228182306, time elapsed: (++0.000000917), Host Name: mendax, Event Name: syscall_exit_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 48, buf = 222501009261744, count = 48, flags = 0'},
#  {'example': 'timestamp:06:13:02.228206097, time elapsed: (++0.000023791), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: uaddr = 260299015465752, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228206513, time elapsed: (++0.000000416), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 0, uaddr = 260299015465752, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228207305, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: uaddr = 260299016648640, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228207472, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 0, uaddr = 260299016648640, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228279970, time elapsed: (++0.000072498), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665337344'},
#  {'example': 'timestamp:06:13:02.228280511, time elapsed: (++0.000000541), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665337344'},
#  {'example': 'timestamp:06:13:02.228303511, time elapsed: (++0.000023000), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: brk = 222501009473536'},
#  {'example': 'timestamp:06:13:02.228304094, time elapsed: (++0.000000583), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 222501009473536'},
#  {'example': 'timestamp:06:13:02.228349843, time elapsed: (++0.000045749), Host Name: mendax, Event Name: syscall_entry_getrandom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: buf = 203053665260704, count = 48, flags = 0'},
#  {'example': 'timestamp:06:13:02.228350635, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_exit_getrandom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 48, buf = 203053665260704, count = 48, flags = 0'},
#  {'example': 'timestamp:06:13:02.228373676, time elapsed: (++0.000023041), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247448, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228374009, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247448, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228374592, time elapsed: (++0.000000583), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960195430336, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228374967, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960195430336, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228375759, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: uaddr = 260299015465996, op = 129, val = 2147483647, utime = 0, uaddr2 = 222501009395736, val3 = 228626440'},
#  {'example': 'timestamp:06:13:02.228376009, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 0, uaddr = 260299015465996, uaddr2 = 222501009395736'},
#  {'example': 'timestamp:06:13:02.228438549, time elapsed: (++0.000062540), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228438841, time elapsed: (++0.000000292), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228441091, time elapsed: (++0.000002250), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228441174, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228443799, time elapsed: (++0.000002625), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228443882, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228444340, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228444382, time elapsed: (++0.000000042), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228446215, time elapsed: (++0.000001833), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228446257, time elapsed: (++0.000000042), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228447465, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228447549, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228448674, time elapsed: (++0.000001125), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228448757, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228449132, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228449174, time elapsed: (++0.000000042), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228450382, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228450465, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228450799, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228450882, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228469173, time elapsed: (++0.000018291), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665472512'},
#  {'example': 'timestamp:06:13:02.228469673, time elapsed: (++0.000000500), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665472512'},
#  {'example': 'timestamp:06:13:02.228476548, time elapsed: (++0.000006875), Host Name: mendax, Event Name: syscall_exit_ppoll, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 1, nfds = 16, fds_length = 1, overflow = 0, fds = [ [0] = {{ fd = 29, raw_events = 0x1, events = {{ POLLIN = 1, POLLPRI = 0, POLLOUT = 0, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.228493797, time elapsed: (++0.000017249), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: fd = 3, buf = 281474090967200, count = 8'},
#  {'example': 'timestamp:06:13:02.228494214, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 8'},
#  {'example': 'timestamp:06:13:02.228552379, time elapsed: (++0.000058165), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228552629, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 3154'},
#  {'example': 'timestamp:06:13:02.228564212, time elapsed: (++0.000011583), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247692, op = 129, val = 2147483647, utime = 0, uaddr2 = 203053665394872, val3 = 496541864'},
#  {'example': 'timestamp:06:13:02.228564421, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247692, uaddr2 = 203053665394872'},
#  {'example': 'timestamp:06:13:02.228624502, time elapsed: (++0.000060081), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228624711, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228626752, time elapsed: (++0.000002041), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228626836, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228629252, time elapsed: (++0.000002416), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228629335, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228629752, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228629835, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228631585, time elapsed: (++0.000001750), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228631669, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228632835, time elapsed: (++0.000001166), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228632919, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228634127, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228634210, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228634585, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228634669, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228635877, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228635960, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228636335, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228636419, time elapsed: (++0.000000084), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228637002, time elapsed: (++0.000000583), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194245452, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228637252, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194245452, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228656835, time elapsed: (++0.000019583), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665607680'},
#  {'example': 'timestamp:06:13:02.228657335, time elapsed: (++0.000000500), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665607680'},
#  {'example': 'timestamp:06:13:02.228660543, time elapsed: (++0.000003208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228660626, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228661418, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228661501, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228674709, time elapsed: (++0.000013208), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228674834, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 14345'},
#  {'example': 'timestamp:06:13:02.228694417, time elapsed: (++0.000019583), Host Name: mendax, Event Name: syscall_entry_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: addr = 248270898528256, len = 7602176'},
#  {'example': 'timestamp:06:13:02.228704875, time elapsed: (++0.000010458), Host Name: mendax, Event Name: syscall_exit_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.228708583, time elapsed: (++0.000003708), Host Name: mendax, Event Name: syscall_entry_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, buff = 203053665469200, len = 517, flags = 16384, addr = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228715167, time elapsed: (++0.000006584), Host Name: mendax, Event Name: syscall_exit_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 517'},
#  {'example': 'timestamp:06:13:02.228717458, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, size = 5, flags = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228718250, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_exit_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -11, ubuf = 203053665491603, addr = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228719833, time elapsed: (++0.000001583), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773656, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.228720041, time elapsed: (++0.000000208), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'},
#  {'example': 'timestamp:06:13:02.228721041, time elapsed: (++0.000001000), Host Name: mendax, Event Name: syscall_entry_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: tsp = 281474913773856, sigmask = 0, sigsetsize = 0, nfds = 2, fds_length = 2, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x1, events = {{ POLLIN = 1, POLLPRI = 0, POLLOUT = 0, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.228726958, time elapsed: (++0.000005917), Host Name: mendax, Event Name: syscall_exit_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 1, fds_length = 0, overflow = 0, fds = [ ]'},
#  {'example': 'timestamp:06:13:02.228729249, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: fd = 547, count = 16'},
#  {'example': 'timestamp:06:13:02.228730083, time elapsed: (++0.000000834), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 8, buf = 246916494319000'},
#  {'example': 'timestamp:06:13:02.228780040, time elapsed: (++0.000049957), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: uaddr = 194557001039240, op = 129, val = 1, utime = 0, uaddr2 = 0, val3 = 3570750768'},
#  {'example': 'timestamp:06:13:02.228782831, time elapsed: (++0.000002791), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 1, uaddr = 194557001039240, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228783040, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: uaddr = 194557001039612, op = 129, val = 1, utime = 0, uaddr2 = 0, val3 = 3572464968'},
#  {'example': 'timestamp:06:13:02.228784331, time elapsed: (++0.000001291), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 1, uaddr = 194557001039612, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228804622, time elapsed: (++0.000020291), Host Name: mendax, Event Name: syscall_exit_epoll_pwait, Cpu Id: 1, process_details: procname = elasticsearch[m, pid = 11822, tid = 11868, kernel_details: ret = 1, fds_length = 0, overflow = 0, fds = [ ]'},
#  {'example': 'timestamp:06:13:02.228807664, time elapsed: (++0.000003042), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 1, process_details: procname = elasticsearch[m, pid = 11822, tid = 11868, kernel_details: fd = 549, count = 16'},
#  {'example': 'timestamp:06:13:02.228808664, time elapsed: (++0.000001000), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 1, process_details: procname = elasticsearch[m, pid = 11822, tid = 11868, kernel_details: ret = 8, buf = 246916493270424'},
#  {'example': 'timestamp:06:13:02.228828913, time elapsed: (++0.000020249), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: uaddr = 260299015463756, op = 129, val = 2147483647, utime = 0, uaddr2 = 0, val3 = 0'},
#  {'example': 'timestamp:06:13:02.228829622, time elapsed: (++0.000000709), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 0, uaddr = 260299015463756, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228850121, time elapsed: (++0.000020499), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: brk = 222501009608704'},
#  {'example': 'timestamp:06:13:02.228851038, time elapsed: (++0.000000917), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 222501009608704'},
#  {'example': 'timestamp:06:13:02.228853871, time elapsed: (++0.000002833), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228854163, time elapsed: (++0.000000292), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228855538, time elapsed: (++0.000001375), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228855621, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228867912, time elapsed: (++0.000012291), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '},
#  {'example': 'timestamp:06:13:02.228868037, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'},
#  {'example': 'timestamp:06:13:02.228900995, time elapsed: (++0.000032958), Host Name: mendax, Event Name: syscall_entry_sendto, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: fd = 4, buff = 222501009470064, len = 517, flags = 16384, addr = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228907953, time elapsed: (++0.000006958), Host Name: mendax, Event Name: syscall_exit_sendto, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 517'},
#  {'example': 'timestamp:06:13:02.228909911, time elapsed: (++0.000001958), Host Name: mendax, Event Name: syscall_entry_recvfrom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: fd = 4, size = 5, flags = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228910453, time elapsed: (++0.000000542), Host Name: mendax, Event Name: syscall_exit_recvfrom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = -11, ubuf = 222501009492467, addr = 0, addr_len = 0'},
#  {'example': 'timestamp:06:13:02.228911745, time elapsed: (++0.000001292), Host Name: mendax, Event Name: syscall_entry_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: epfd = 546, op_enum = ( EPOLL_CTL_ADD : container = 1 ), fd = 573, event = {{ data_union = {{ u64 = 0x70000023D, fd = 573'},
#  {'example': 'timestamp:06:13:02.228912286, time elapsed: (++0.000000541), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: sig = 13, act = 281474642530040, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.228912620, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 0, oact = 0'},
#  {'example': 'timestamp:06:13:02.228913536, time elapsed: (++0.000000916), Host Name: mendax, Event Name: syscall_exit_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.228913911, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_entry_ppoll, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: tsp = 281474642530240, sigmask = 0, sigsetsize = 0, nfds = 2, fds_length = 2, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x1, events = {{ POLLIN = 1, POLLPRI = 0, POLLOUT = 0, POLLERR = 0, POLLHUP = 0, padding = 0'},
#  {'example': 'timestamp:06:13:02.228914245, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_entry_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: epfd = 546, maxevents = 1024, timeout = 10000, sigmask = 0x0, sigsetsize = 8'},
#  {'example': 'timestamp:06:13:02.228915328, time elapsed: (++0.000001083), Host Name: mendax, Event Name: syscall_exit_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 1, fds_length = 0, overflow = 0, fds = [ ]'},
#  {'example': 'timestamp:06:13:02.228917119, time elapsed: (++0.000001791), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = llvmpipe-1, pid = 3154, tid = 3214, kernel_details: ret = 0, uaddr = 194557001039612, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228918161, time elapsed: (++0.000001042), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = llvmpipe-1, pid = 3154, tid = 3214, kernel_details: uaddr = 194557001039528, op = 128, val = 2, utime = 0, uaddr2 = 0, val3 = 2025773224'},
#  {'example': 'timestamp:06:13:02.228919703, time elapsed: (++0.000001542), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: ret = 0, uaddr = 194557001039240, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228920494, time elapsed: (++0.000000791), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: uaddr = 194557001039160, op = 129, val = 1, utime = 0, uaddr2 = 0, val3 = 3572464968'},
#  {'example': 'timestamp:06:13:02.228920661, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: ret = 0, uaddr = 194557001039160, uaddr2 = 0'},
#  {'example': 'timestamp:06:13:02.228921703, time elapsed: (++0.000001042), Host Name: mendax, Event Name: syscall_entry_epoll_ctl, Cpu Id: 1, process_details: procname = elasticsearch[m, pid = 11822, tid = 11868, kernel_details: epfd = 548, op_enum = ( EPOLL_CTL_ADD : container = 1 ), fd = 576, event = {{ data_union = {{ u64 = 0x700000240, fd = 576'},
#  {'example': 'timestamp:06:13:02.228922411, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: fd = 13, cmd = 3222299827, arg = 248272618772584'},
#  {'example': 'timestamp:06:13:02.228923369, time elapsed: (++0.000000958), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: fd = 573, count = 65536'},
#  {'example': 'timestamp:06:13:02.228924703, time elapsed: (++0.000001334), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 517, buf = 246915589475920'},
#  {'example': 'timestamp:06:13:02.228925369, time elapsed: (++0.000000666), Host Name: mendax, Event Name: syscall_exit_epoll_ctl, Cpu Id: 1, process_details: procname = elasticsearch[m, pid = 11822, tid = 11868, kernel_details: ret = 0'},
# ...
#  {'example': 'timestamp:06:13:02.232192824, time elapsed: (++0.000024416), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232193074, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070919, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232193199, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232193365, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070920, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232193490, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232193657, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070925, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232193740, time elapsed: (++0.000000083), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232193907, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070923, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232194032, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232194282, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, buf = 275115481833472, count = 4096'},
#  {'example': 'timestamp:06:13:02.232195740, time elapsed: (++0.000001458), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 4096'},
#  {'example': 'timestamp:06:13:02.232195990, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 139264, nbytes = 4096, flags = 2'},
#  {'example': 'timestamp:06:13:02.232205407, time elapsed: (++0.000009417), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232205907, time elapsed: (++0.000000500), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 135168, nbytes = 4096, flags = 7'},
#  {'example': 'timestamp:06:13:02.232206198, time elapsed: (++0.000000291), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232206448, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 135168, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232207407, time elapsed: (++0.000000959), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 135168, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232207740, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 62982, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232207990, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232208323, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 62981, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232233031, time elapsed: (++0.000024708), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232233281, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070919, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232233406, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232233573, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070920, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232233698, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232233823, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070925, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232233948, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232234114, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070923, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232234239, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232234489, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, buf = 275115481837568, count = 4096'},
#  {'example': 'timestamp:06:13:02.232236239, time elapsed: (++0.000001750), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 4096'},
#  {'example': 'timestamp:06:13:02.232236447, time elapsed: (++0.000000208), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 143360, nbytes = 4096, flags = 2'},
#  {'example': 'timestamp:06:13:02.232244864, time elapsed: (++0.000008417), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232245322, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 139264, nbytes = 4096, flags = 7'},
#  {'example': 'timestamp:06:13:02.232245572, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232245822, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 139264, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232246697, time elapsed: (++0.000000875), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 139264, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232247031, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 62982, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232247281, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232247655, time elapsed: (++0.000000374), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 62981, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232273030, time elapsed: (++0.000025375), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232273321, time elapsed: (++0.000000291), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070919, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232273488, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656752'},
#  {'example': 'timestamp:06:13:02.232273655, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070920, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232273821, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656760'},
#  {'example': 'timestamp:06:13:02.232273988, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070925, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232274155, time elapsed: (++0.000000167), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656768'},
#  {'example': 'timestamp:06:13:02.232274321, time elapsed: (++0.000000166), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 2148070923, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232274446, time elapsed: (++0.000000125), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115444656688'},
#  {'example': 'timestamp:06:13:02.232274738, time elapsed: (++0.000000292), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, buf = 275115481833472, count = 4096'},
#  {'example': 'timestamp:06:13:02.232276238, time elapsed: (++0.000001500), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 4096'},
#  {'example': 'timestamp:06:13:02.232276488, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 147456, nbytes = 4096, flags = 2'},
#  {'example': 'timestamp:06:13:02.232284738, time elapsed: (++0.000008250), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232285154, time elapsed: (++0.000000416), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 143360, nbytes = 4096, flags = 7'},
#  {'example': 'timestamp:06:13:02.232285404, time elapsed: (++0.000000250), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'},
#  {'example': 'timestamp:06:13:02.232285613, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 143360, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232286446, time elapsed: (++0.000000833), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 143360, len = 4096, advice = 4'},
#  {'example': 'timestamp:06:13:02.232286779, time elapsed: (++0.000000333), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 34, cmd = 62982, arg = 275115481893672'},
#  {'example': 'timestamp:06:13:02.232286988, time elapsed: (++0.000000209), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, arg = 275115481893672'}]

# %%
def extract_unique_event_examples(examples):
    seen_events = set()
    unique_examples = []

    for item in examples:
        example_text = item.get("example", "")

        # Try to extract the Event Name
        try:
            event_name = example_text.split("Event Name:")[1].split(",")[0].strip()
        except IndexError:
            continue  # Skip if malformed

        if event_name not in seen_events:
            seen_events.add(event_name)
            unique_examples.append(item)

    return unique_examples

# %%
filtered_examples = extract_unique_event_examples(logs)

# Print unique event names and count
print(f"Total unique events: {len(filtered_examples)}")
for ex in filtered_examples:
    print(ex)
# Out:
# Total unique events: 48
# {'example': 'timestamp:06:13:02.227908688, time elapsed: (++?.?????????), Host Name: mendax, Event Name: syscall_entry_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 553, upeer_addrlen = 246916502706640'}
# {'example': 'timestamp:06:13:02.227912438, time elapsed: (++0.000003750), Host Name: mendax, Event Name: syscall_exit_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 576, upeer_sockaddr = 246916502706648, upeer_addrlen = 246916502706640'}
# {'example': 'timestamp:06:13:02.227914646, time elapsed: (++0.000002208), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 3, arg = 50'}
# {'example': 'timestamp:06:13:02.227914980, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 2, arg = 50'}
# {'example': 'timestamp:06:13:02.227916313, time elapsed: (++0.000001333), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, usockaddr_len = 246916502706368'}
# {'example': 'timestamp:06:13:02.227916771, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, usockaddr = 246916502706376, usockaddr_len = 246916502706368'}
# {'example': 'timestamp:06:13:02.227927646, time elapsed: (++0.000003292), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 6, optname = 1, optval = 246916502705868, optlen = 4'}
# {'example': 'timestamp:06:13:02.227928063, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.227928771, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502705996'}
# {'example': 'timestamp:06:13:02.227929146, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706080, optlen = 246916502705996'}
# {'example': 'timestamp:06:13:02.227938146, time elapsed: (++0.000002417), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 549, buf = 246916502706248, count = 8'}
# {'example': 'timestamp:06:13:02.227940521, time elapsed: (++0.000002375), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 8'}
# {'example': 'timestamp:06:13:02.227944020, time elapsed: (++0.000003499), Host Name: mendax, Event Name: syscall_entry_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: epfd = 542, maxevents = 1024, timeout = -1, sigmask = 0x0, sigsetsize = 8'}
# {'example': 'timestamp:06:13:02.227946729, time elapsed: (++0.000002709), Host Name: mendax, Event Name: syscall_exit_connect, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -115'}
# {'example': 'timestamp:06:13:02.227949604, time elapsed: (++0.000001542), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773656, sigsetsize = 8'}
# {'example': 'timestamp:06:13:02.227949979, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'}
# {'example': 'timestamp:06:13:02.227951854, time elapsed: (++0.000001875), Host Name: mendax, Event Name: syscall_entry_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: tsp = 281474913773856, sigmask = 0, sigsetsize = 0, nfds = 2, fds_length = 2, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x4, events = {{ POLLIN = 0, POLLPRI = 0, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'}
# {'example': 'timestamp:06:13:02.227953062, time elapsed: (++0.000001208), Host Name: mendax, Event Name: syscall_exit_ppoll, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 1, nfds = 2, fds_length = 1, overflow = 0, fds = [ [0] = {{ fd = 4, raw_events = 0x4, events = {{ POLLIN = 0, POLLPRI = 0, POLLOUT = 1, POLLERR = 0, POLLHUP = 0, padding = 0'}
# {'example': 'timestamp:06:13:02.227959145, time elapsed: (++0.000003125), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247760, op = 129, val = 2147483647, utime = 0, uaddr2 = 203053665022808, val3 = 496169800'}
# {'example': 'timestamp:06:13:02.227961395, time elapsed: (++0.000002250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247760, uaddr2 = 203053665022808'}
# {'example': 'timestamp:06:13:02.228003894, time elapsed: (++0.000042499), Host Name: mendax, Event Name: syscall_entry_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: '}
# {'example': 'timestamp:06:13:02.228005269, time elapsed: (++0.000001375), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'}
# {'example': 'timestamp:06:13:02.228012394, time elapsed: (++0.000007125), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665202176'}
# {'example': 'timestamp:06:13:02.228013435, time elapsed: (++0.000001041), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665202176'}
# {'example': 'timestamp:06:13:02.228181389, time elapsed: (++0.000006833), Host Name: mendax, Event Name: syscall_entry_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: buf = 222501009261744, count = 48, flags = 0'}
# {'example': 'timestamp:06:13:02.228182306, time elapsed: (++0.000000917), Host Name: mendax, Event Name: syscall_exit_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 48, buf = 222501009261744, count = 48, flags = 0'}
# {'example': 'timestamp:06:13:02.228694417, time elapsed: (++0.000019583), Host Name: mendax, Event Name: syscall_entry_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: addr = 248270898528256, len = 7602176'}
# {'example': 'timestamp:06:13:02.228704875, time elapsed: (++0.000010458), Host Name: mendax, Event Name: syscall_exit_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.228708583, time elapsed: (++0.000003708), Host Name: mendax, Event Name: syscall_entry_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, buff = 203053665469200, len = 517, flags = 16384, addr = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228715167, time elapsed: (++0.000006584), Host Name: mendax, Event Name: syscall_exit_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 517'}
# {'example': 'timestamp:06:13:02.228717458, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, size = 5, flags = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228718250, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_exit_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -11, ubuf = 203053665491603, addr = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228726958, time elapsed: (++0.000005917), Host Name: mendax, Event Name: syscall_exit_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 1, fds_length = 0, overflow = 0, fds = [ ]'}
# {'example': 'timestamp:06:13:02.228729249, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: fd = 547, count = 16'}
# {'example': 'timestamp:06:13:02.228730083, time elapsed: (++0.000000834), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 8, buf = 246916494319000'}
# {'example': 'timestamp:06:13:02.228911745, time elapsed: (++0.000001292), Host Name: mendax, Event Name: syscall_entry_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: epfd = 546, op_enum = ( EPOLL_CTL_ADD : container = 1 ), fd = 573, event = {{ data_union = {{ u64 = 0x70000023D, fd = 573'}
# {'example': 'timestamp:06:13:02.228913536, time elapsed: (++0.000000916), Host Name: mendax, Event Name: syscall_exit_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.228922411, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: fd = 13, cmd = 3222299827, arg = 248272618772584'}
# {'example': 'timestamp:06:13:02.228925369, time elapsed: (++0.000000000), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: ret = 0, arg = 248272618772584'}
# {'example': 'timestamp:06:13:02.229356066, time elapsed: (++0.000191495), Host Name: mendax, Event Name: syscall_entry_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 4'}
# {'example': 'timestamp:06:13:02.229357316, time elapsed: (++0.000001250), Host Name: mendax, Event Name: syscall_exit_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.229359066, time elapsed: (++0.000001750), Host Name: mendax, Event Name: syscall_entry_recvmsg, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 6, msg = 281474329849072, flags = 16384'}
# {'example': 'timestamp:06:13:02.229393523, time elapsed: (++0.000000833), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, nbytes = 4096, flags = 2'}
# {'example': 'timestamp:06:13:02.229429022, time elapsed: (++0.000035499), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.229865552, time elapsed: (++0.000001458), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, len = 4096, advice = 4'}
# {'example': 'timestamp:06:13:02.229868636, time elapsed: (++0.000003084), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 0, len = 4096, advice = 4'}
# {'example': 'timestamp:06:13:02.229904385, time elapsed: (++0.000001125), Host Name: mendax, Event Name: syscall_entry_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ufd = 67, flags = 1, utmr = 281458146600112'}
# {'example': 'timestamp:06:13:02.229905385, time elapsed: (++0.000001000), Host Name: mendax, Event Name: syscall_exit_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ret = 0, otmr = 0'}

# %%
def escape_curly_braces(examples):
    return [{"example": ex["example"].replace("{", "").replace("}", "}}")} for ex in examples]

filtered_examples = escape_curly_braces(filtered_examples)

# %%
import re

def remove_high_risk_examples(examples):
    safe_examples = []
    for ex in examples:
        example_text = ex["example"]

        # Remove examples with problematic patterns
        if any([
            re.search(r"\{.*?\}", example_text),               # Unescaped curly braces
            re.search(r"\[\s*\d+\s*\]\s*=", example_text),     # Patterns like [0] =
            "fds =" in example_text,                           # Explicit fds structures
            "events =" in example_text and "POLL" in example_text  # POLLIN/POLLOUT structures
        ]):
            continue  # Skip high-risk example
        safe_examples.append(ex)

    return safe_examples

# %%
filtered_examples = remove_high_risk_examples(filtered_examples)
print(f"Remaining safe examples: {len(filtered_examples)}")
# Out:
# Remaining safe examples: 45

# %%
filtered_examples = filtered_examples[1:]

# %%
filtered_examples = [
    row for row in filtered_examples
    if not row["example"].strip().endswith("kernel_details:")
]

# %%
# Print unique event names and count
print(f"Total unique events: {len(filtered_examples)}")
for ex in filtered_examples:
    print(ex)
# Out:
# Total unique events: 43
# {'example': 'timestamp:06:13:02.227912438, time elapsed: (++0.000003750), Host Name: mendax, Event Name: syscall_exit_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 576, upeer_sockaddr = 246916502706648, upeer_addrlen = 246916502706640'}
# {'example': 'timestamp:06:13:02.227914646, time elapsed: (++0.000002208), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 3, arg = 50'}
# {'example': 'timestamp:06:13:02.227914980, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 2, arg = 50'}
# {'example': 'timestamp:06:13:02.227916313, time elapsed: (++0.000001333), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, usockaddr_len = 246916502706368'}
# {'example': 'timestamp:06:13:02.227916771, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, usockaddr = 246916502706376, usockaddr_len = 246916502706368'}
# {'example': 'timestamp:06:13:02.227927646, time elapsed: (++0.000003292), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 6, optname = 1, optval = 246916502705868, optlen = 4'}
# {'example': 'timestamp:06:13:02.227928063, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.227928771, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502705996'}
# {'example': 'timestamp:06:13:02.227929146, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706080, optlen = 246916502705996'}
# {'example': 'timestamp:06:13:02.227938146, time elapsed: (++0.000002417), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 549, buf = 246916502706248, count = 8'}
# {'example': 'timestamp:06:13:02.227940521, time elapsed: (++0.000002375), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 8'}
# {'example': 'timestamp:06:13:02.227944020, time elapsed: (++0.000003499), Host Name: mendax, Event Name: syscall_entry_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: epfd = 542, maxevents = 1024, timeout = -1, sigmask = 0x0, sigsetsize = 8'}
# {'example': 'timestamp:06:13:02.227946729, time elapsed: (++0.000002709), Host Name: mendax, Event Name: syscall_exit_connect, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -115'}
# {'example': 'timestamp:06:13:02.227949604, time elapsed: (++0.000001542), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773656, sigsetsize = 8'}
# {'example': 'timestamp:06:13:02.227949979, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'}
# {'example': 'timestamp:06:13:02.227959145, time elapsed: (++0.000003125), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247760, op = 129, val = 2147483647, utime = 0, uaddr2 = 203053665022808, val3 = 496169800'}
# {'example': 'timestamp:06:13:02.227961395, time elapsed: (++0.000002250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247760, uaddr2 = 203053665022808'}
# {'example': 'timestamp:06:13:02.228005269, time elapsed: (++0.000001375), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'}
# {'example': 'timestamp:06:13:02.228012394, time elapsed: (++0.000007125), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665202176'}
# {'example': 'timestamp:06:13:02.228013435, time elapsed: (++0.000001041), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665202176'}
# {'example': 'timestamp:06:13:02.228181389, time elapsed: (++0.000006833), Host Name: mendax, Event Name: syscall_entry_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: buf = 222501009261744, count = 48, flags = 0'}
# {'example': 'timestamp:06:13:02.228182306, time elapsed: (++0.000000917), Host Name: mendax, Event Name: syscall_exit_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 48, buf = 222501009261744, count = 48, flags = 0'}
# {'example': 'timestamp:06:13:02.228694417, time elapsed: (++0.000019583), Host Name: mendax, Event Name: syscall_entry_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: addr = 248270898528256, len = 7602176'}
# {'example': 'timestamp:06:13:02.228704875, time elapsed: (++0.000010458), Host Name: mendax, Event Name: syscall_exit_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.228708583, time elapsed: (++0.000003708), Host Name: mendax, Event Name: syscall_entry_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, buff = 203053665469200, len = 517, flags = 16384, addr = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228715167, time elapsed: (++0.000006584), Host Name: mendax, Event Name: syscall_exit_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 517'}
# {'example': 'timestamp:06:13:02.228717458, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, size = 5, flags = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228718250, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_exit_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -11, ubuf = 203053665491603, addr = 0, addr_len = 0'}
# {'example': 'timestamp:06:13:02.228729249, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: fd = 547, count = 16'}
# {'example': 'timestamp:06:13:02.228730083, time elapsed: (++0.000000834), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 8, buf = 246916494319000'}
# {'example': 'timestamp:06:13:02.228911745, time elapsed: (++0.000001292), Host Name: mendax, Event Name: syscall_entry_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: epfd = 546, op_enum = ( EPOLL_CTL_ADD : container = 1 ), fd = 573, event =  data_union =  u64 = 0x70000023D, fd = 573'}
# {'example': 'timestamp:06:13:02.228913536, time elapsed: (++0.000000916), Host Name: mendax, Event Name: syscall_exit_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.228922411, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: fd = 13, cmd = 3222299827, arg = 248272618772584'}
# {'example': 'timestamp:06:13:02.228925369, time elapsed: (++0.000000000), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: ret = 0, arg = 248272618772584'}
# {'example': 'timestamp:06:13:02.229356066, time elapsed: (++0.000191495), Host Name: mendax, Event Name: syscall_entry_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 4'}
# {'example': 'timestamp:06:13:02.229357316, time elapsed: (++0.000001250), Host Name: mendax, Event Name: syscall_exit_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.229359066, time elapsed: (++0.000001750), Host Name: mendax, Event Name: syscall_entry_recvmsg, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 6, msg = 281474329849072, flags = 16384'}
# {'example': 'timestamp:06:13:02.229393523, time elapsed: (++0.000000833), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, nbytes = 4096, flags = 2'}
# {'example': 'timestamp:06:13:02.229429022, time elapsed: (++0.000035499), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'}
# {'example': 'timestamp:06:13:02.229865552, time elapsed: (++0.000001458), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, len = 4096, advice = 4'}
# {'example': 'timestamp:06:13:02.229868636, time elapsed: (++0.000003084), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 0, len = 4096, advice = 4'}
# {'example': 'timestamp:06:13:02.229904385, time elapsed: (++0.000001125), Host Name: mendax, Event Name: syscall_entry_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ufd = 67, flags = 1, utmr = 281458146600112'}
# {'example': 'timestamp:06:13:02.229905385, time elapsed: (++0.000001000), Host Name: mendax, Event Name: syscall_exit_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ret = 0, otmr = 0'}

# %%
del filtered_examples[17]

# %%
del filtered_examples[30]

# %%
# Print unique event names and count
print(f"Total unique events: {len(filtered_examples)}")
i = 0
for ex in filtered_examples:
    print(f"i: {i}", ex)
    i += 1
# Out:
# Total unique events: 42
# i: 0 {'example': 'timestamp:06:13:02.227912438, time elapsed: (++0.000003750), Host Name: mendax, Event Name: syscall_exit_accept, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 576, upeer_sockaddr = 246916502706648, upeer_addrlen = 246916502706640'}
# i: 1 {'example': 'timestamp:06:13:02.227914646, time elapsed: (++0.000002208), Host Name: mendax, Event Name: syscall_entry_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, cmd = 3, arg = 50'}
# i: 2 {'example': 'timestamp:06:13:02.227914980, time elapsed: (++0.000000334), Host Name: mendax, Event Name: syscall_exit_fcntl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 2, arg = 50'}
# i: 3 {'example': 'timestamp:06:13:02.227916313, time elapsed: (++0.000001333), Host Name: mendax, Event Name: syscall_entry_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, usockaddr_len = 246916502706368'}
# i: 4 {'example': 'timestamp:06:13:02.227916771, time elapsed: (++0.000000458), Host Name: mendax, Event Name: syscall_exit_getsockname, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, usockaddr = 246916502706376, usockaddr_len = 246916502706368'}
# i: 5 {'example': 'timestamp:06:13:02.227927646, time elapsed: (++0.000003292), Host Name: mendax, Event Name: syscall_entry_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 6, optname = 1, optval = 246916502705868, optlen = 4'}
# i: 6 {'example': 'timestamp:06:13:02.227928063, time elapsed: (++0.000000417), Host Name: mendax, Event Name: syscall_exit_setsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0'}
# i: 7 {'example': 'timestamp:06:13:02.227928771, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 576, level = 1, optname = 7, optlen = 246916502705996'}
# i: 8 {'example': 'timestamp:06:13:02.227929146, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_getsockopt, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 0, optval = 246916502706080, optlen = 246916502705996'}
# i: 9 {'example': 'timestamp:06:13:02.227938146, time elapsed: (++0.000002417), Host Name: mendax, Event Name: syscall_entry_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: fd = 549, buf = 246916502706248, count = 8'}
# i: 10 {'example': 'timestamp:06:13:02.227940521, time elapsed: (++0.000002375), Host Name: mendax, Event Name: syscall_exit_write, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: ret = 8'}
# i: 11 {'example': 'timestamp:06:13:02.227944020, time elapsed: (++0.000003499), Host Name: mendax, Event Name: syscall_entry_epoll_pwait, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11859, kernel_details: epfd = 542, maxevents = 1024, timeout = -1, sigmask = 0x0, sigsetsize = 8'}
# i: 12 {'example': 'timestamp:06:13:02.227946729, time elapsed: (++0.000002709), Host Name: mendax, Event Name: syscall_exit_connect, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -115'}
# i: 13 {'example': 'timestamp:06:13:02.227949604, time elapsed: (++0.000001542), Host Name: mendax, Event Name: syscall_entry_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: sig = 13, act = 281474913773656, sigsetsize = 8'}
# i: 14 {'example': 'timestamp:06:13:02.227949979, time elapsed: (++0.000000375), Host Name: mendax, Event Name: syscall_exit_rt_sigaction, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, oact = 0'}
# i: 15 {'example': 'timestamp:06:13:02.227959145, time elapsed: (++0.000003125), Host Name: mendax, Event Name: syscall_entry_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: uaddr = 267960194247760, op = 129, val = 2147483647, utime = 0, uaddr2 = 203053665022808, val3 = 496169800'}
# i: 16 {'example': 'timestamp:06:13:02.227961395, time elapsed: (++0.000002250), Host Name: mendax, Event Name: syscall_exit_futex, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 0, uaddr = 267960194247760, uaddr2 = 203053665022808'}
# i: 17 {'example': 'timestamp:06:13:02.228005269, time elapsed: (++0.000001375), Host Name: mendax, Event Name: syscall_exit_getpid, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 14344'}
# i: 18 {'example': 'timestamp:06:13:02.228012394, time elapsed: (++0.000007125), Host Name: mendax, Event Name: syscall_entry_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: brk = 203053665202176'}
# i: 19 {'example': 'timestamp:06:13:02.228013435, time elapsed: (++0.000001041), Host Name: mendax, Event Name: syscall_exit_brk, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 203053665202176'}
# i: 20 {'example': 'timestamp:06:13:02.228181389, time elapsed: (++0.000006833), Host Name: mendax, Event Name: syscall_entry_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: buf = 222501009261744, count = 48, flags = 0'}
# i: 21 {'example': 'timestamp:06:13:02.228182306, time elapsed: (++0.000000917), Host Name: mendax, Event Name: syscall_exit_getrandom, Cpu Id: 3, process_details: procname = curl, pid = 14344, tid = 14344, kernel_details: ret = 48, buf = 222501009261744, count = 48, flags = 0'}
# i: 22 {'example': 'timestamp:06:13:02.228694417, time elapsed: (++0.000019583), Host Name: mendax, Event Name: syscall_entry_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: addr = 248270898528256, len = 7602176'}
# i: 23 {'example': 'timestamp:06:13:02.228704875, time elapsed: (++0.000010458), Host Name: mendax, Event Name: syscall_exit_munmap, Cpu Id: 3, process_details: procname = gnome-shell, pid = 3154, tid = 3154, kernel_details: ret = 0'}
# i: 24 {'example': 'timestamp:06:13:02.228708583, time elapsed: (++0.000003708), Host Name: mendax, Event Name: syscall_entry_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, buff = 203053665469200, len = 517, flags = 16384, addr = 0, addr_len = 0'}
# i: 25 {'example': 'timestamp:06:13:02.228715167, time elapsed: (++0.000006584), Host Name: mendax, Event Name: syscall_exit_sendto, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = 517'}
# i: 26 {'example': 'timestamp:06:13:02.228717458, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: fd = 4, size = 5, flags = 0, addr_len = 0'}
# i: 27 {'example': 'timestamp:06:13:02.228718250, time elapsed: (++0.000000792), Host Name: mendax, Event Name: syscall_exit_recvfrom, Cpu Id: 2, process_details: procname = curl, pid = 14345, tid = 14345, kernel_details: ret = -11, ubuf = 203053665491603, addr = 0, addr_len = 0'}
# i: 28 {'example': 'timestamp:06:13:02.228729249, time elapsed: (++0.000002291), Host Name: mendax, Event Name: syscall_entry_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: fd = 547, count = 16'}
# i: 29 {'example': 'timestamp:06:13:02.228730083, time elapsed: (++0.000000834), Host Name: mendax, Event Name: syscall_exit_read, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 8, buf = 246916494319000'}
# i: 30 {'example': 'timestamp:06:13:02.228913536, time elapsed: (++0.000000916), Host Name: mendax, Event Name: syscall_exit_epoll_ctl, Cpu Id: 2, process_details: procname = elasticsearch[m, pid = 11822, tid = 11867, kernel_details: ret = 0'}
# i: 31 {'example': 'timestamp:06:13:02.228922411, time elapsed: (++0.000000708), Host Name: mendax, Event Name: syscall_entry_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: fd = 13, cmd = 3222299827, arg = 248272618772584'}
# i: 32 {'example': 'timestamp:06:13:02.228925369, time elapsed: (++0.000000000), Host Name: mendax, Event Name: syscall_exit_ioctl, Cpu Id: 3, process_details: procname = llvmpipe-0, pid = 3154, tid = 3213, kernel_details: ret = 0, arg = 248272618772584'}
# i: 33 {'example': 'timestamp:06:13:02.229356066, time elapsed: (++0.000191495), Host Name: mendax, Event Name: syscall_entry_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 4'}
# i: 34 {'example': 'timestamp:06:13:02.229357316, time elapsed: (++0.000001250), Host Name: mendax, Event Name: syscall_exit_close, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: ret = 0'}
# i: 35 {'example': 'timestamp:06:13:02.229359066, time elapsed: (++0.000001750), Host Name: mendax, Event Name: syscall_entry_recvmsg, Cpu Id: 0, process_details: procname = lttng-runas, pid = 14324, tid = 14324, kernel_details: fd = 6, msg = 281474329849072, flags = 16384'}
# i: 36 {'example': 'timestamp:06:13:02.229393523, time elapsed: (++0.000000833), Host Name: mendax, Event Name: syscall_entry_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, nbytes = 4096, flags = 2'}
# i: 37 {'example': 'timestamp:06:13:02.229429022, time elapsed: (++0.000035499), Host Name: mendax, Event Name: syscall_exit_sync_file_range, Cpu Id: 0, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0'}
# i: 38 {'example': 'timestamp:06:13:02.229865552, time elapsed: (++0.000001458), Host Name: mendax, Event Name: syscall_entry_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: fd = 35, offset = 0, len = 4096, advice = 4'}
# i: 39 {'example': 'timestamp:06:13:02.229868636, time elapsed: (++0.000003084), Host Name: mendax, Event Name: syscall_exit_fadvise64_64, Cpu Id: 3, process_details: procname = lttng-consumerd, pid = 14323, tid = 14330, kernel_details: ret = 0, fd = 35, offset = 0, len = 4096, advice = 4'}
# i: 40 {'example': 'timestamp:06:13:02.229904385, time elapsed: (++0.000001125), Host Name: mendax, Event Name: syscall_entry_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ufd = 67, flags = 1, utmr = 281458146600112'}
# i: 41 {'example': 'timestamp:06:13:02.229905385, time elapsed: (++0.000001000), Host Name: mendax, Event Name: syscall_exit_timerfd_settime, Cpu Id: 1, process_details: procname = data-loop.0, pid = 2932, tid = 2972, kernel_details: ret = 0, otmr = 0'}

# %%
class LinuxLog(BaseModel):
    timestamp: str  # Log timestamp
    time_elapsed: Optional[str]  # Time elapsed since the previous log
    host_name: Optional[str]  # Host name
    event_name: Optional[str]  # Event name
    cpu_id: Optional[int]  # CPU ID where the event occurred
    process_details: Optional[str] # Details object
    kernel_details: Optional[str] # Details object

# %%
schema = LinuxLog.model_json_schema()

# %%
schema
# Out:
# {'properties': {'timestamp': {'title': 'Timestamp', 'type': 'string'},
#   'time_elapsed': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'title': 'Time Elapsed'},
#   'host_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'title': 'Host Name'},
#   'event_name': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'title': 'Event Name'},
#   'cpu_id': {'anyOf': [{'type': 'integer'}, {'type': 'null'}],
#    'title': 'Cpu Id'},
#   'process_details': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'title': 'Process Details'},
#   'kernel_details': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'title': 'Kernel Details'}},
#  'required': ['timestamp',
#   'time_elapsed',
#   'host_name',
#   'event_name',
#   'cpu_id',
#   'process_details',
#   'kernel_details'],
#  'title': 'LinuxLog',
#  'type': 'object'}

# %%
all_synthetic_results = []

# %%
import time
from pydantic import ValidationError
from openai import OpenAIError

total = 10
batch_size = 100
example_batch_size = 10
num_examples = len(filtered_examples)

# Metrics
total_requests = 0
total_tokens = 0

for i in range(total):
    print(f"[Batch {i+1}/{total}] Generating...")

    # Dynamically pick 10 examples per batch, loop if out of range
    start = (i * example_batch_size) % num_examples
    end = start + example_batch_size
    current_examples = filtered_examples[start:end]

    OPENAI_TEMPLATE = PromptTemplate(input_variables=["example"], template="{example}")

    prompt_template = FewShotPromptTemplate(
        prefix= SYNTHETIC_FEW_SHOT_PREFIX,
        examples=current_examples,
        suffix=SYNTHETIC_FEW_SHOT_SUFFIX,
        input_variables=["subject", "extra"],
        example_prompt=OPENAI_TEMPLATE,
    )

    synthetic_data_generator = create_openai_data_generator(
        output_schema=LinuxLog,
        llm=ChatOpenAI(
            model="gpt-4.1-mini", # Change model to GPT-3.5-Turbo
            model_kwargs={"top_p": 0.95},
            temperature=1,
            api_key=os.environ["OPENAI_API_KEY"]
        ),
        prompt=prompt_template,
    )

    try:
        synthetic_results = synthetic_data_generator.generate(
          subject="Linux Logs using LLTNG tool",
          extra="""You are an AI trained to generate valid realistic Linux LTTng logs in JSON format.
                   Each generated log must include the following fields: timestamp, time_elapsed, host_name, event_name, cpu_id, process_details, and kernel_details fields.
                    - process details should include only procname, pid, and tid fields with realistic values. No other field is permitted here. Example, process_details='procname = nginx, pid = 12542, tid = 12543'
                    - kernel_details should include relevant kernel parameters based on procname in LTTng format. Example kernel_details field should like, kernel_details='fd = 34, buf = 314159265358979, count = 1024'
                    - each process should have a relevant event_name, kernel parameters. Values must reflect realistic log content. Ensure all fields are filled and correctly typed.
                    - Omit any values that doesn't fit LTTng Linux log format. Do not generate any unrealistic values. Each field should have relevant values, timestamp values like 06:13:02.227946563, time_elapsed like (++0.000008417), host_name always synthetic_host,
                      event_name like syscall_entry_read, cpu_id like 1 containing cpu core numbers, process_details like procname = nginx, pid = 12542, tid = 12543, kernel_details like fd = 34, buf = 314159265358979, count = 1024
                    - Valid output format: timestamp='06:13:02.227946563', time_elapsed='(++0.000008417)', host_name='synthetic-host', event_name='syscall_entry_read', cpu_id=3, process_details='procname = nginx, pid = 12542, tid = 12543', kernel_details='fd = 34, buf = 314159265358979, count = 1024'
                    - Do not omit or leave any fields blank. The host_name value must always be synthetic-host
                """,
          runs=batch_size,
          safe=True,  # silently skips invalid output
        )
        all_synthetic_results.extend(synthetic_results)

        total_requests += 1
        estimated_tokens = batch_size * 1000
        total_tokens += estimated_tokens

        print(f"Batch {i+1}: {len(synthetic_results)} logs")
        print(f"Total Requests so far: {total_requests}")
        print(f"Estimated Tokens used so far: {total_tokens:,}")

    except ValidationError as e:
        print("Skipping invalid result due to validation error.")
        continue
    except OpenAIError as e:
        print(f"OpenAI Error: {e}")
        break

    time.sleep(61)

print(f"Total synthetic logs generated: {len(all_synthetic_results)}")
print(f"Final estimated usage: {total_tokens:,} tokens, {total_requests} API calls")
# Out:
# [Batch 1/1] Generating...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-26-91264935.py in <cell line: 0>()
#      41
#      42     try:
# ---> 43         synthetic_results = synthetic_data_generator.generate(
#      44           subject="Linux Logs using LLTNG tool",
#      45           extra = """You are an AI trained to generate valid realistic Linux LTTng logs in JSON object format.
#
# /usr/local/lib/python3.11/dist-packages/langchain_experimental/tabular_synthetic_data/base.py in generate(self, subject, runs, *args, **kwargs)
#      99             )
#     100         for _ in range(runs):
# --> 101             result = self.llm_chain.run(subject=subject, *args, **kwargs)
#     102             self.results.append(result)
#     103             self._update_examples(result)
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     187                 warned = True
#     188                 emit_warning()
# --> 189             return wrapped(*args, **kwargs)
#     190
#     191         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     606
#     607         if kwargs and not args:
# --> 608             return self(kwargs, callbacks=callbacks, tags=tags, metadata=metadata)[
#     609                 _output_key
#     610             ]
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     187                 warned = True
#     188                 emit_warning()
# --> 189             return wrapped(*args, **kwargs)
#     190
#     191         async def awarning_emitting_wrapper(*args: Any, **kwargs: Any) -> Any:
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in __call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     384         }
#     385
# --> 386         return self.invoke(
#     387             inputs,
#     388             cast(RunnableConfig, {k: v for k, v in config.items() if v is not None}),
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     165         except BaseException as e:
#     166             run_manager.on_chain_error(e)
# --> 167             raise e
#     168         run_manager.on_chain_end(outputs)
#     169
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/base.py in invoke(self, input, config, **kwargs)
#     155             self._validate_inputs(inputs)
#     156             outputs = (
# --> 157                 self._call(inputs, run_manager=run_manager)
#     158                 if new_arg_supported
#     159                 else self._call(inputs)
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in _call(self, inputs, run_manager)
#     125         run_manager: Optional[CallbackManagerForChainRun] = None,
#     126     ) -> dict[str, str]:
# --> 127         response = self.generate([inputs], run_manager=run_manager)
#     128         return self.create_outputs(response)[0]
#     129
#
# /usr/local/lib/python3.11/dist-packages/langchain/chains/llm.py in generate(self, input_list, run_manager)
#     137         callbacks = run_manager.get_child() if run_manager else None
#     138         if isinstance(self.llm, BaseLanguageModel):
# --> 139             return self.llm.generate_prompt(
#     140                 prompts,
#     141                 stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#     961     ) -> LLMResult:
#     962         prompt_messages = [p.to_messages() for p in prompts]
# --> 963         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#     964
#     965     @override
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     780             try:
#     781                 results.append(
# --> 782                     self._generate_with_cache(
#     783                         m,
#     784                         stop=stop,
#
# /usr/local/lib/python3.11/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1026             result = generate_from_stream(iter(chunks))
#    1027         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1028             result = self._generate(
#    1029                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1030             )
#
# /usr/local/lib/python3.11/dist-packages/langchain_openai/chat_models/base.py in _generate(self, messages, stop, run_manager, **kwargs)
#    1128             generation_info = {"headers": dict(raw_response.headers)}
#    1129         else:
# -> 1130             response = self.client.create(**payload)
#    1131         return self._create_chat_result(response, generation_info)
#    1132
#
# /usr/local/lib/python3.11/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     285                         msg = f"Missing required argument: {quote(missing[0])}"
#     286                 raise TypeError(msg)
# --> 287             return func(*args, **kwargs)
#     288
#     289         return wrapper  # type: ignore
#
# /usr/local/lib/python3.11/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, reasoning_effort, response_format, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1085     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1086         validate_response_format(response_format)
# -> 1087         return self._post(
#    1088             "/chat/completions",
#    1089             body=maybe_transform(
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1247         body: Body | None = None,
#    1248         options: RequestOptions = {},
# -> 1249         files: RequestFiles | None = None,
#    1250         stream: bool = False,
#    1251         stream_cls: type[_StreamT] | None = None,
#
# /usr/local/lib/python3.11/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#     970                 kwargs["auth"] = self.custom_auth
#     971
# --> 972             if options.follow_redirects is not None:
#     973                 kwargs["follow_redirects"] = options.follow_redirects
#     974
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in send(self, request, stream, auth, follow_redirects)
#     912         auth = self._build_request_auth(request, auth)
#     913
# --> 914         response = self._send_handling_auth(
#     915             request,
#     916             auth=auth,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_auth(self, request, auth, follow_redirects, history)
#     940
#     941             while True:
# --> 942                 response = self._send_handling_redirects(
#     943                     request,
#     944                     follow_redirects=follow_redirects,
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_handling_redirects(self, request, follow_redirects, history)
#     977                 hook(request)
#     978
# --> 979             response = self._send_single_request(request)
#     980             try:
#     981                 for hook in self._event_hooks["response"]:
#
# /usr/local/lib/python3.11/dist-packages/httpx/_client.py in _send_single_request(self, request)
#    1012
#    1013         with request_context(request=request):
# -> 1014             response = transport.handle_request(request)
#    1015
#    1016         assert isinstance(response.stream, SyncByteStream)
#
# /usr/local/lib/python3.11/dist-packages/httpx/_transports/default.py in handle_request(self, request)
#     248         )
#     249         with map_httpcore_exceptions():
# --> 250             resp = self._pool.handle_request(req)
#     251
#     252         assert isinstance(resp.stream, typing.Iterable)
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     254
#     255             self._close_connections(closing)
# --> 256             raise exc from None
#     257
#     258         # Return the response. Note that in this case we still have to manage
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection_pool.py in handle_request(self, request)
#     234                 try:
#     235                     # Send the request on the assigned connection.
# --> 236                     response = connection.handle_request(
#     237                         pool_request.request
#     238                     )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/connection.py in handle_request(self, request)
#     101             raise exc
#     102
# --> 103         return self._connection.handle_request(request)
#     104
#     105     def _connect(self, request: Request) -> NetworkStream:
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     134                 with Trace("response_closed", logger, request) as trace:
#     135                     self._response_closed()
# --> 136             raise exc
#     137
#     138     # Sending the request...
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in handle_request(self, request)
#     104                     headers,
#     105                     trailing_data,
# --> 106                 ) = self._receive_response_headers(**kwargs)
#     107                 trace.return_value = (
#     108                     http_version,
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_response_headers(self, request)
#     175
#     176         while True:
# --> 177             event = self._receive_event(timeout=timeout)
#     178             if isinstance(event, h11.Response):
#     179                 break
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_sync/http11.py in _receive_event(self, timeout)
#     215
#     216             if event is h11.NEED_DATA:
# --> 217                 data = self._network_stream.read(
#     218                     self.READ_NUM_BYTES, timeout=timeout
#     219                 )
#
# /usr/local/lib/python3.11/dist-packages/httpcore/_backends/sync.py in read(self, max_bytes, timeout)
#     126         with map_exceptions(exc_map):
#     127             self._sock.settimeout(timeout)
# --> 128             return self._sock.recv(max_bytes)
#     129
#     130     def write(self, buffer: bytes, timeout: float | None = None) -> None:
#
# /usr/lib/python3.11/ssl.py in recv(self, buflen, flags)
#    1293                     "non-zero flags not allowed in calls to recv() on %s" %
#    1294                     self.__class__)
# -> 1295             return self.read(buflen)
#    1296         else:
#    1297             return super().recv(buflen, flags)
#
# /usr/lib/python3.11/ssl.py in read(self, len, buffer)
#    1166                 return self._sslobj.read(len, buffer)
#    1167             else:
# -> 1168                 return self._sslobj.read(len)
#    1169         except SSLError as x:
#    1170             if x.args[0] == SSL_ERROR_EOF and self.suppress_ragged_eofs:
#
# KeyboardInterrupt:

# %%
all_synthetic_results

# %%
len(all_synthetic_results)

# %%
len(synthetic_results)

# %%
with open("synthetic_logs_1K_openAI.txt", "w") as f:
    for item in all_synthetic_results:
        f.write(str(item) + "\n")

# %%
import re
import pandas as pd

# Flatten the entries into raw strings
raw_entries = [str(entry) for entry in all_synthetic_results]

# Define a flexible regex that matches both formats
pattern = re.compile(
    r"timestamp='([^']+)'[\s,]*"
    r"time_elapsed='([^']+)'[\s,]*"
    r"host_name='([^']+)'[\s,]*"
    r"event_name='([^']+)'[\s,]*"
    r"cpu_id=(\d+)[\s,]*"
    r"process_details='([^']+)'[\s,]*"
    r"kernel_details='([^']+)'"
)

# Extract matching entries
parsed_logs = []
for entry in raw_entries:
    match = pattern.search(entry)
    if match:
        parsed_logs.append({
            "timestamp": match.group(1),
            "time_elapsed": match.group(2),
            "host_name": match.group(3),
            "event_name": match.group(4),
            "cpu_id": int(match.group(5)),
            "process_details": match.group(6),
            "kernel_details": match.group(7)
        })

# Convert to DataFrame
df = pd.DataFrame(parsed_logs)

# %%
df

# %%
df.to_csv("synthetic_linux_logs_1K_GPT-o4-mini.csv", index=False)
